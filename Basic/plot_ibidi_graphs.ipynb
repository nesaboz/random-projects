# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline   

folder = r'Z:\ibidi test'
file = '2018_04_pera_logColdLeft.txt'
df = pd.read_csv(os.path.join(folder, file), header=1, names=['time', 'a', 'b', 'c', 'd', 'e'])
df['a'] = df['a'].str.strip('[').astype(float)
df['e'] = df['e'].str.strip(']').astype(float)
df.head()

# %%
col_names = df.columns[1:]

# %%
fig  = plt.subplots(3, 2, sharex=True, sharey=True)
col_names = df.columns[1:]
col_names

for k in range(5):
    plt.subplot(3, 2, k + 1)
    plt.plot(df[col_names[k]])

    # 
    # bars = axs[k].bar(xval, yval, width = 1, edgecolor='b')
    # (_, caps, _) = axs[k].errorbar(xval, yval, yerr=tstd, fmt='.', markersize=1, capsize=20, color='k')
    # for cap in caps:
    #     cap.set_markeredgewidth(1)
    # 
    # axs[k].set_xticks(xval, labels)
    # y_entry = y_entries[k]
    # axs[k].plot([1991.5, 1995.5], [y_entry, y_entry], 'k--', lw=2)
    # # ax = plt.gca()
    # axs[k].set_facecolor((1, 1, 1))
    # axs[k].axis(frameon=True)
    # axs[k].set_frame_on(True)
    # axs[k].axhline(y=0, color='k')
    # axs[k].set_title('y value = {}'.format(y_entry), fontsize=8)
    # # set the x-spine (see below for more info on `set_position`)
    # axs[k].spines['left'].set_color('k')
    # 
    # # turn off the right spine/ticks
    # axs[k].spines['bottom'].set_color('k')
    # # axs[k].yaxis.tick_left()
    # 
    # for i, bar in enumerate(bars):
    #     bar.set_linewidth(1)
    # 
    #     if y_entry > yval[i] + tstd.values[i]:
    #         bar.set_color('r')
    #     elif y_entry < yval[i] - tstd.values[i]:
    #         bar.set_color('b')
    #     else:
    #         bar.set_color('w')
    #         bar.set_edgecolor('k')




# df['a']
# df.head()

# %%
# df.columns = ['time', 'a', 'b', 'c', 'd', 'e']
df.head()

# %%
df.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>ColdLeft</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Mon Apr 23 14:09:30 2018</th>
#       <th>[19.899999999999999</th>
#       <th>4.58</th>
#       <th>30.06</th>
#       <th>47.97</th>
#       <td>19.07]</td>
#     </tr>
#     <tr>
#       <th>Mon Apr 23 14:09:31 2018</th>
#       <th>[17.329999999999998</th>
#       <th>4.67</th>
#       <th>30.07</th>
#       <th>47.98</th>
#       <td>18.850000000000001]</td>
#     </tr>
#     <tr>
#       <th>Mon Apr 23 14:09:32 2018</th>
#       <th>[17.329999999999998</th>
# ...
